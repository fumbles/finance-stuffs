# %%
import yfinance as yf
import pandas as pd
from tabulate import tabulate

tickers = yf.Tickers('ENPH TQQQ VOO MA MSCI CROX BX FICO')

# Access each ticker using (example)
for ticker in tickers.tickers:
    # Print title
    print(f"===== {ticker} Info =====")
    
    # Print ticker info with indentation
    ticker_info = tickers.tickers[ticker].info.copy()
    ticker_info_str = {str(key): val for key, val in ticker_info.items()}
    print(tabulate(ticker_info_str.items(), tablefmt='plain'))
    
    # Print a gap
    print("\n")
    
    # Print title
    print(f"===== {ticker} Historical Data =====")
    
    # Convert Timestamps to strings in the historical_data dictionary
    historical_data = tickers.tickers[ticker].history(period='1mo')
    historical_data_str = historical_data.reset_index().to_dict(orient='list')
    
    # Convert Series objects to lists
    for key, val in historical_data_str.items():
        if isinstance(val, pd.Series):
            historical_data_str[key] = val.tolist()
        elif isinstance(val[0], pd.Timestamp):
            historical_data_str[key] = [str(date) for date in val]
    
    # Print historical data in a table
    historical_data_table = {k: historical_data_str[k] for k in ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']}
    print(tabulate(historical_data_table, headers='keys', tablefmt='plain'))
    
    # Print a gap
    print("\n")
    
    # Print title
    print(f"===== {ticker} Actions =====")
    
    # Convert Series objects to lists in the actions data
    actions = tickers.tickers[ticker].actions.copy()
    actions_str = {str(key): val.tolist() if isinstance(val, pd.Series) else val for key, val in actions.items()}
    print(tabulate(actions_str.items(), tablefmt='plain'))
    
    # Print a gap
    print("\n")
# Out:
# ===== ENPH Info =====
# address1                      47281 Bayside Parkway
# city                          Fremont
# state                         CA
# zip                           94538
# country                       United States
# phone                         707-774-7000
# website                       https://www.enphase.com
# industry                      Solar
# industryKey                   solar
# industryDisp                  Solar
# sector                        Technology
# sectorKey                     technology
# sectorDisp                    Technology
# longBusinessSummary           Enphase Energy, Inc., together with its subsidiaries, designs, develops, manufactures, and sells home energy solutions for the solar photovoltaic industry in the United States and internationally. The company offers semiconductor-based microinverter, which converts energy at the individual solar module level, and combines with its proprietary networking and software technologies to provide energy monitoring and control services. It also provides microinverter units and related accessories, an IQ gateway; IQ batteries; the cloud-based Enlighten monitoring service; storage solutions; and electric vehicle charging solutions; and design, proposal, permitting, and lead generation services. The company sells its solutions to solar distributors; and directly to large installers, original equipment manufacturers, strategic partners, and homeowners, as well as through its legacy product upgrade program or online store. Enphase Energy, Inc. was incorporated in 2006 and is headquartered in Fremont, California.
# fullTimeEmployees             2821
# companyOfficers               [{'maxAge': 1, 'name': 'Mr. Badrinarayanan  Kothandaraman', 'age': 50, 'title': 'President, CEO & Director', 'yearBorn': 1973, 'fiscalYear': 2022, 'totalPay': 1016777, 'exercisedValue': 154239104, 'unexercisedValue': 246441808}, {'maxAge': 1, 'name': 'Ms. Mandy  Yang', 'age': 47, 'title': 'VP & CFO', 'yearBorn': 1976, 'fiscalYear': 2022, 'totalPay': 745341, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. David A. Ranhoff', 'age': 67, 'title': 'Executive VP & Chief Commercial Officer', 'yearBorn': 1956, 'fiscalYear': 2022, 'totalPay': 793895, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Jeffrey  McNeil', 'age': 61, 'title': 'Chief Advisor', 'yearBorn': 1962, 'fiscalYear': 2022, 'totalPay': 808351, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Martin  Fornage', 'age': 59, 'title': 'Co-Founder', 'yearBorn': 1964, 'fiscalYear': 2022, 'totalPay': 233256, 'exercisedValue': 0, 'unexercisedValue': 1544307}, {'maxAge': 1, 'name': 'Mr. Raghuveer R. Belur', 'age': 55, 'title': 'Co-Founder & Chief Products Officer', 'yearBorn': 1968, 'fiscalYear': 2022, 'totalPay': 164881, 'exercisedValue': 0, 'unexercisedValue': 1187596}, {'maxAge': 1, 'name': 'Mr. Ron  Swenson', 'title': 'Vice President of Operations', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Hans Van Antwerpen', 'title': 'VP & CTO', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Karen  Sagot', 'title': 'Head Of Investor Relations', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Lisan  Hung', 'age': 54, 'title': 'VP, General Counsel & Corporate Secretary', 'yearBorn': 1969, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk                     4
# boardRisk                     9
# compensationRisk              8
# shareHolderRightsRisk         10
# overallRisk                   9
# governanceEpochDate           1704067200
# compensationAsOfEpochDate     1672444800
# maxAge                        86400
# priceHint                     2
# previousClose                 117.06
# open                          117.01
# dayLow                        114.02
# dayHigh                       117.64
# regularMarketPreviousClose    117.06
# regularMarketOpen             117.01
# regularMarketDayLow           114.02
# regularMarketDayHigh          117.64
# beta                          1.617
# trailingPE                    29.532663
# forwardPE                     28.18705
# volume                        2738454
# regularMarketVolume           2738454
# averageVolume                 5647760
# averageVolume10days           3747390
# averageDailyVolume10Day       3747390
# bidSize                       900
# askSize                       1100
# marketCap                     16050205696
# fiftyTwoWeekLow               73.49
# fiftyTwoWeekHigh              260.98
# priceToSalesTrailing12Months  5.9163237
# fiftyDayAverage               104.3918
# twoHundredDayAverage          143.29425
# currency                      USD
# enterpriseValue               15533590528
# profitMargins                 0.21076
# floatShares                   131141085
# sharesOutstanding             136551008
# sharesShort                   12242487
# sharesShortPriorMonth         14666816
# sharesShortPreviousMonthDate  1700006400
# dateShortInterest             1702598400
# sharesPercentSharesOut        0.089700006
# heldPercentInsiders           0.02961
# heldPercentInstitutions       0.77995
# shortRatio                    2.21
# shortPercentOfFloat           0.1187
# impliedSharesOutstanding      136551008
# bookValue                     7.456
# priceToBook                   15.764485
# lastFiscalYearEnd             1672444800
# nextFiscalYearEnd             1703980800
# mostRecentQuarter             1696032000
# earningsQuarterlyGrowth       -0.007
# netIncomeToCommon             571769984
# trailingEps                   3.98
# forwardEps                    4.17
# pegRatio                      2.43
# enterpriseToRevenue           5.726
# enterpriseToEbitda            22.901
# 52WeekChange                  -0.51572067
# SandP52WeekChange             0.19414937
# exchange                      NGM
# quoteType                     EQUITY
# symbol                        ENPH
# underlyingSymbol              ENPH
# shortName                     Enphase Energy, Inc.
# longName                      Enphase Energy, Inc.
# firstTradeDateEpochUtc        1333114200
# timeZoneFullName              America/New_York
# timeZoneShortName             EST
# uuid                          5e94a4bb-e413-3d84-9d5f-c49df8281b53
# messageBoardId                finmb_40485464
# gmtOffSetMilliseconds         -18000000
# currentPrice                  117.54
# targetHighPrice               255.0
# targetLowPrice                76.0
# targetMeanPrice               124.88
# targetMedianPrice             123.0
# recommendationMean            2.4
# recommendationKey             buy
# numberOfAnalystOpinions       34
# totalCash                     1783884032
# totalCashPerShare             13.104
# ebitda                        678286976
# totalDebt                     1316723968
# quickRatio                    3.078
# currentRatio                  3.356
# totalRevenue                  2712868096
# debtToEquity                  129.765
# revenuePerShare               19.885
# returnOnAssets                0.1236
# returnOnEquity                0.70382005
# grossProfits                  974595000
# freeCashflow                  541964736
# operatingCashflow             915043968
# earningsGrowth                0.007
# revenueGrowth                 -0.132
# grossMargins                  0.45060003
# ebitdaMargins                 0.25003
# operatingMargins              0.2141
# financialCurrency             USD
# trailingPegRatio              5.3602
#
#
# ===== ENPH Historical Data =====
# Date                         Open    High     Low    Close    Volume    Dividends    Stock Splits
# 2023-12-11 00:00:00-05:00  100.61  105.24  100.14   103.55   3796500            0               0
# 2023-12-12 00:00:00-05:00  102.61  102.64   96.69    99.82   5668800            0               0
# 2023-12-13 00:00:00-05:00   95.8   108.28   95.2    107.61   7319000            0               0
# 2023-12-14 00:00:00-05:00  113.82  123.84  113.52   120.22  14495500            0               0
# 2023-12-15 00:00:00-05:00  125.82  126.2   120.72   123.92  17196000            0               0
# 2023-12-18 00:00:00-05:00  121.32  126     120.78   124.03   5779100            0               0
# 2023-12-19 00:00:00-05:00  126.56  136.2   125.5    135.32  10574100            0               0
# 2023-12-20 00:00:00-05:00  134.6   136.05  127.87   128      7121500            0               0
# 2023-12-21 00:00:00-05:00  130.87  134.6   129.39   133.86   4966500            0               0
# 2023-12-22 00:00:00-05:00  135.87  137.08  132.04   133.99   4143100            0               0
# 2023-12-26 00:00:00-05:00  134.56  139.65  133.96   137.34   3625600            0               0
# 2023-12-27 00:00:00-05:00  138.03  138.35  134.84   135.63   3750200            0               0
# 2023-12-28 00:00:00-05:00  134.96  137.19  133.45   134.79   2665100            0               0
# 2023-12-29 00:00:00-05:00  134.22  135.95  131.89   132.14   2811100            0               0
# 2024-01-02 00:00:00-05:00  130.66  135.65  128.67   131.24   3039300            0               0
# 2024-01-03 00:00:00-05:00  126.82  127.3   119.52   122.63   6025500            0               0
# 2024-01-04 00:00:00-05:00  120.22  121.52  117.6    118.07   3928200            0               0
# 2024-01-05 00:00:00-05:00  115.18  119.87  114.52   115.39   4182400            0               0
# 2024-01-08 00:00:00-05:00  119.44  119.65  115.4    116      4657600            0               0
# 2024-01-09 00:00:00-05:00  114.22  118.21  113.13   117.06   2788900            0               0
# 2024-01-10 00:00:00-05:00  117.01  117.64  114.01   117.54   2767800            0               0
#
#
# ===== ENPH Actions =====
# Dividends     []
# Stock Splits  []
#
#
# ===== TQQQ Info =====
# longBusinessSummary         The fund invests in financial instruments that ProShare Advisors believes, in combination, should produce daily returns consistent with the Daily Target. The index includes 100 of the largest domestic and international non-financial companies listed on The Nasdaq Stock Market based on market capitalization. The fund is non-diversified.
# maxAge                      86400
# priceHint                   2
# previousClose               49.07
# open                        49.17
# dayLow                      48.8401
# dayHigh                     50.41
# regularMarketPreviousClose  49.07
# regularMarketOpen           49.17
# regularMarketDayLow         48.8401
# regularMarketDayHigh        50.41
# volume                      72743245
# regularMarketVolume         72743245
# averageVolume               96633309
# averageVolume10days         68015560
# averageDailyVolume10Day     68015560
# bidSize                     1800
# askSize                     800
# yield                       0.0126
# totalAssets                 20467056640
# fiftyTwoWeekLow             18.58
# fiftyTwoWeekHigh            52.01
# fiftyDayAverage             44.1564
# twoHundredDayAverage        37.9864
# navPrice                    49.1033
# currency                    USD
# category                    Trading--Leveraged Equity
# ytdReturn                   -0.0321499
# beta3Year                   3.47
# fundFamily                  ProShares
# fundInceptionDate           1265673600
# legalType                   Exchange Traded Fund
# threeYearAverageReturn      0.0182315
# fiveYearAverageReturn       0.37041292
# exchange                    NGM
# quoteType                   ETF
# symbol                      TQQQ
# underlyingSymbol            TQQQ
# shortName                   ProShares UltraPro QQQ
# longName                    ProShares UltraPro QQQ
# firstTradeDateEpochUtc      1265898600
# timeZoneFullName            America/New_York
# timeZoneShortName           EST
# uuid                        e44544e4-318f-3f5a-8077-5d451edcee89
# messageBoardId              finmb_98126597
# gmtOffSetMilliseconds       -18000000
# trailingPegRatio
#
#
# ===== TQQQ Historical Data =====
# Date                          Open     High      Low    Close     Volume    Dividends    Stock Splits
# 2023-12-11 00:00:00-05:00  44.4748  45.8786  44.4051  45.7691   75770000        0                   0
# 2023-12-12 00:00:00-05:00  45.779   46.8941  45.3708  46.8742   71449700        0                   0
# 2023-12-13 00:00:00-05:00  47.1729  48.8555  46.8941  48.527   115040700        0                   0
# 2023-12-14 00:00:00-05:00  49.0347  49.5126  47.3422  48.4473  101348900        0                   0
# 2023-12-15 00:00:00-05:00  48.7261  49.5724  48.4871  49.0248   78130400        0                   0
# 2023-12-18 00:00:00-05:00  49.2737  50.3788  49.1542  50.0503   58218000        0                   0
# 2023-12-19 00:00:00-05:00  50.1996  50.8368  50.1399  50.797    60174800        0                   0
# 2023-12-20 00:00:00-05:00  50.48    51.27    48.46    48.54     88082500        0.223               0
# 2023-12-21 00:00:00-05:00  49.89    50.27    48.94    50.15     74544700        0                   0
# 2023-12-22 00:00:00-05:00  50.6     50.94    49.64    50.35     66114200        0                   0
# 2023-12-26 00:00:00-05:00  50.64    51.51    50.62    51.27     43685600        0                   0
# 2023-12-27 00:00:00-05:00  51.35    51.66    51.02    51.54     55747800        0                   0
# 2023-12-28 00:00:00-05:00  51.92    52.01    51.27    51.41     42884100        0                   0
# 2023-12-29 00:00:00-05:00  51.38    51.52    50       50.7      66986200        0                   0
# 2024-01-02 00:00:00-05:00  49.35    49.43    47.27    48.13     88135300        0                   0
# 2024-01-03 00:00:00-05:00  47.17    47.54    46.43    46.59     83906100        0                   0
# 2024-01-04 00:00:00-05:00  45.87    46.97    45.73    45.81     71867700        0                   0
# 2024-01-05 00:00:00-05:00  45.86    46.92    45.47    45.98     85039900        0                   0
# 2024-01-08 00:00:00-05:00  46.39    48.9     46.33    48.75     67687100        0                   0
# 2024-01-09 00:00:00-05:00  47.66    49.41    47.61    49.07     74215800        0                   0
# 2024-01-10 00:00:00-05:00  49.17    50.41    48.84    50.04     73337800        0                   0
#
#
# ===== TQQQ Actions =====
# Dividends      [0.223]
# Stock Splits   [0.0]
# Capital Gains  [0.0]
#
#
# ===== VOO Info =====
# phone                        800-523-1036
# longBusinessSummary          The fund employs an indexing investment approach designed to track the performance of the Standard & Poor's 500 Index, a widely recognized benchmark of U.S. stock market performance that is dominated by the stocks of large U.S. companies. The advisor attempts to replicate the target index by investing all, or substantially all, of its assets in the stocks that make up the index, holding each stock in approximately the same proportion as its weighting in the index.
# maxAge                       86400
# priceHint                    2
# previousClose                435.07
# open                         435.77
# dayLow                       435.49
# dayHigh                      438.735
# regularMarketPreviousClose   435.07
# regularMarketOpen            435.77
# regularMarketDayLow          435.49
# regularMarketDayHigh         438.735
# trailingPE                   23.857431
# volume                       4261170
# regularMarketVolume          4261170
# averageVolume                4975968
# averageVolume10days          5589630
# averageDailyVolume10Day      5589630
# bidSize                      1000
# askSize                      900
# yield                        0.0146
# totalAssets                  980347977728
# fiftyTwoWeekLow              349.76
# fiftyTwoWeekHigh             438.84
# fiftyDayAverage              418.5376
# twoHundredDayAverage         401.36804
# trailingAnnualDividendRate   5.437
# trailingAnnualDividendYield  0.012496839
# navPrice                     435.56
# currency                     USD
# category                     Large Blend
# ytdReturn                    -0.0039606
# beta3Year                    1.0
# fundFamily                   Vanguard
# fundInceptionDate            1283817600
# legalType                    Exchange Traded Fund
# threeYearAverageReturn       0.091448
# fiveYearAverageReturn        0.1483843
# exchange                     PCX
# quoteType                    ETF
# symbol                       VOO
# underlyingSymbol             VOO
# shortName                    Vanguard S&P 500 ETF
# longName                     Vanguard 500 Index Fund
# firstTradeDateEpochUtc       1284039000
# timeZoneFullName             America/New_York
# timeZoneShortName            EST
# uuid                         367519e5-61d9-3b17-9298-4635221f9752
# messageBoardId               finmb_28117396
# gmtOffSetMilliseconds        -18000000
# trailingPegRatio
#
#
# ===== VOO Historical Data =====
# Date                          Open     High      Low    Close    Volume    Dividends    Stock Splits
# 2023-12-11 00:00:00-05:00  420.674  422.964  420.485  422.815   5247100        0                   0
# 2023-12-12 00:00:00-05:00  422.476  424.916  421.53   424.916   5982600        0                   0
# 2023-12-13 00:00:00-05:00  425.125  430.832  424.757  430.702   8659100        0                   0
# 2023-12-14 00:00:00-05:00  432.435  433.571  429.468  431.967   8349100        0                   0
# 2023-12-15 00:00:00-05:00  431.41   432.465  430.463  431.31    5281900        0                   0
# 2023-12-18 00:00:00-05:00  432.854  434.606  432.664  433.75    4280500        0                   0
# 2023-12-19 00:00:00-05:00  434.248  436.419  434.158  436.389   4061500        0                   0
# 2023-12-20 00:00:00-05:00  435.51   437.31   429.9    430.09    5783200        1.801               0
# 2023-12-21 00:00:00-05:00  433.13   434.64   430.86   434.28    4621600        0                   0
# 2023-12-22 00:00:00-05:00  435.46   436.84   433.48   435.29    4035200        0                   0
# 2023-12-26 00:00:00-05:00  435.67   437.92   435.58   437.1     3835800        0                   0
# 2023-12-27 00:00:00-05:00  436.9    438.02   436.42   437.9     4271000        0                   0
# 2023-12-28 00:00:00-05:00  438.25   438.84   437.66   437.97    4703700        0                   0
# 2023-12-29 00:00:00-05:00  437.87   438.34   434.94   436.8     4374400        0                   0
# 2024-01-02 00:00:00-05:00  433.91   435.27   432.36   434.01    9076000        0                   0
# 2024-01-03 00:00:00-05:00  432.32   433      430.25   430.79    4805000        0                   0
# 2024-01-04 00:00:00-05:00  430.33   432.78   429.21   429.43    3945300        0                   0
# 2024-01-05 00:00:00-05:00  429.59   432.3    428.64   429.98    5723100        0                   0
# 2024-01-08 00:00:00-05:00  430.45   436.27   430.37   436.13    7222400        0                   0
# 2024-01-09 00:00:00-05:00  433.62   436.43   433.16   435.07    7939600        0                   0
# 2024-01-10 00:00:00-05:00  435.77   438.74   435.48   437.94    4263000        0                   0
#
#
# ===== VOO Actions =====
# Dividends      [1.801]
# Stock Splits   [0.0]
# Capital Gains  [0.0]
#
#
# ===== MA Info =====
# address1                      2000 Purchase Street
# city                          Purchase
# state                         NY
# zip                           10577
# country                       United States
# phone                         914 249 2000
# website                       https://www.mastercard.com
# industry                      Credit Services
# industryKey                   credit-services
# industryDisp                  Credit Services
# sector                        Financial Services
# sectorKey                     financial-services
# sectorDisp                    Financial Services
# longBusinessSummary           Mastercard Incorporated, a technology company, provides transaction processing and other payment-related products and services in the United States and internationally. It facilitates the processing of payment transactions, including authorization, clearing, and settlement, as well as delivers other payment-related products and services. The company offers integrated products and value-added services for account holders, merchants, financial institutions, businesses, governments, and other organizations, such as programs that enable issuers to provide consumers with credits to defer payments; payment products and solutions that allow its customers to access funds in deposit and other accounts; prepaid programs services; and commercial credit, debit, and prepaid payment products and solutions. It also provides value-added products and services comprising cyber and intelligence solutions for parties to transact, as well as proprietary insights, drawing on principled use of consumer, and merchant data services. In addition, the company offers analytics, test and learn, consulting, managed services, loyalty, processing, and payment gateway solutions for e-commerce merchants. Further, it provides open banking and digital identity platforms services. The company offers payment solutions and services under the MasterCard, Maestro, and Cirrus. Mastercard Incorporated was founded in 1966 and is headquartered in Purchase, New York.
# fullTimeEmployees             29900
# companyOfficers               [{'maxAge': 1, 'name': 'Mr. Michael  Miebach', 'age': 55, 'title': 'CEO & Director', 'yearBorn': 1968, 'fiscalYear': 2022, 'totalPay': 6319001, 'exercisedValue': 0, 'unexercisedValue': 17500972}, {'maxAge': 1, 'name': 'Mr. Sachin  Mehra', 'age': 52, 'title': 'Chief Financial Officer', 'yearBorn': 1971, 'fiscalYear': 2022, 'totalPay': 2987728, 'exercisedValue': 1349388, 'unexercisedValue': 8988374}, {'maxAge': 1, 'name': 'Mr. Timothy Henry Murphy', 'age': 55, 'title': 'Chief Administrative Officer', 'yearBorn': 1968, 'fiscalYear': 2022, 'totalPay': 2252917, 'exercisedValue': 2851496, 'unexercisedValue': 5274128}, {'maxAge': 1, 'name': 'Mr. Craig E. Vosburg', 'age': 56, 'title': 'Chief Product Officer', 'yearBorn': 1967, 'fiscalYear': 2022, 'totalPay': 2269154, 'exercisedValue': 3272267, 'unexercisedValue': 26124436}, {'maxAge': 1, 'name': 'Mr. Edward Grunde McLaughlin', 'age': 57, 'title': 'President & Chief Technology Officer', 'yearBorn': 1966, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Devin  Corr', 'title': 'Executive Vice President of Investor Relations', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Rob  Beard', 'title': 'Chief Legal Officer, General Counsel & Head of Global Policy', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Raja  Rajamannar', 'age': 61, 'title': 'Chief Marketing & Communications Officer', 'yearBorn': 1962, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Greg  Ulrich', 'title': 'Executive Vice President of Strategy, Corporate Development and M&A', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Michael  Fraccaro', 'age': 57, 'title': 'Chief People Officer', 'yearBorn': 1966, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk                     1
# boardRisk                     3
# compensationRisk              5
# shareHolderRightsRisk         3
# overallRisk                   1
# governanceEpochDate           1704067200
# compensationAsOfEpochDate     1672444800
# maxAge                        86400
# priceHint                     2
# previousClose                 422.6
# open                          426.0
# dayLow                        424.1501
# dayHigh                       429.47
# regularMarketPreviousClose    422.6
# regularMarketOpen             426.0
# regularMarketDayLow           424.1501
# regularMarketDayHigh          429.47
# dividendRate                  2.64
# dividendYield                 0.0062
# exDividendDate                1704672000
# payoutRatio                   0.1918
# fiveYearAvgDividendYield      0.51
# beta                          1.093
# trailingPE                    37.305748
# forwardPE                     32.91852
# volume                        2685474
# regularMarketVolume           2685474
# averageVolume                 2575750
# averageVolume10days           2037400
# averageDailyVolume10Day       2037400
# bidSize                       900
# askSize                       800
# marketCap                     401621319680
# fiftyTwoWeekLow               340.21
# fiftyTwoWeekHigh              429.47
# priceToSalesTrailing12Months  16.482182
# fiftyDayAverage               407.5588
# twoHundredDayAverage          392.6466
# trailingAnnualDividendRate    2.28
# trailingAnnualDividendYield   0.0053951726
# currency                      USD
# enterpriseValue               409765347328
# profitMargins                 0.44852
# floatShares                   929195410
# sharesOutstanding             930438016
# sharesShort                   4886847
# sharesShortPriorMonth         4708776
# sharesShortPreviousMonthDate  1700006400
# dateShortInterest             1702598400
# sharesPercentSharesOut        0.0052
# heldPercentInsiders           0.10551
# heldPercentInstitutions       0.78708
# shortRatio                    1.8
# shortPercentOfFloat           0.0058999998
# impliedSharesOutstanding      7723880
# bookValue                     6.721
# priceToBook                   63.72117
# lastFiscalYearEnd             1672444800
# nextFiscalYearEnd             1703980800
# mostRecentQuarter             1696032000
# earningsQuarterlyGrowth       0.28
# netIncomeToCommon             10929000448
# trailingEps                   11.48
# forwardEps                    13.01
# pegRatio                      2.0
# lastSplitFactor               10:1
# lastSplitDate                 1390348800
# enterpriseToRevenue           16.816
# enterpriseToEbitda            27.722
# 52WeekChange                  0.1126616
# SandP52WeekChange             0.19414937
# lastDividendValue             0.66
# lastDividendDate              1704672000
# exchange                      NYQ
# quoteType                     EQUITY
# symbol                        MA
# underlyingSymbol              MA
# shortName                     Mastercard Incorporated
# longName                      Mastercard Incorporated
# firstTradeDateEpochUtc        1148563800
# timeZoneFullName              America/New_York
# timeZoneShortName             EST
# uuid                          2a603965-5313-3f5d-ab1e-43523b62c374
# messageBoardId                finmb_6477196
# gmtOffSetMilliseconds         -18000000
# currentPrice                  428.27
# targetHighPrice               474.81
# targetLowPrice                374.37
# targetMeanPrice               420.1
# targetMedianPrice             420.03
# recommendationMean            1.9
# recommendationKey             buy
# numberOfAnalystOpinions       36
# totalCash                     7491999744
# totalCashPerShare             7.989
# ebitda                        14780999680
# totalDebt                     15566000128
# quickRatio                    0.786
# currentRatio                  1.17
# totalRevenue                  24366999552
# debtToEquity                  243.943
# revenuePerShare               25.649
# returnOnAssets                0.22648
# returnOnEquity                1.70446
# grossProfits                  22237000000
# freeCashflow                  10093625344
# operatingCashflow             10949999616
# earningsGrowth                0.314
# revenueGrowth                 0.135
# grossMargins                  1.0
# ebitdaMargins                 0.6066
# operatingMargins              0.5884
# financialCurrency             USD
# trailingPegRatio              1.4366
#
#
# ===== MA Historical Data =====
# Date                          Open     High      Low    Close    Volume    Dividends    Stock Splits
# 2023-12-11 00:00:00-05:00  411.811  415.515  411.731  415.056   2236000         0                  0
# 2023-12-12 00:00:00-05:00  416.344  420.337  414.047  420.088   2736500         0                  0
# 2023-12-13 00:00:00-05:00  421.196  425.699  418.49   424.012   3694200         0                  0
# 2023-12-14 00:00:00-05:00  424.341  425.18   415.246  417.901   3989700         0                  0
# 2023-12-15 00:00:00-05:00  411.971  418.6    410.952  417.911   5566600         0                  0
# 2023-12-18 00:00:00-05:00  418.87   424.421  418.87   423.762   2686900         0                  0
# 2023-12-19 00:00:00-05:00  423.383  426.009  421.855  424.8     2256200         0                  0
# 2023-12-20 00:00:00-05:00  424.411  426.937  418.58   418.79    3058300         0                  0
# 2023-12-21 00:00:00-05:00  421.126  423.233  419.948  422.774   2213600         0                  0
# 2023-12-22 00:00:00-05:00  424.082  426.498  422.294  423.433   1759000         0                  0
# 2023-12-26 00:00:00-05:00  424.331  425.05   422.284  423.003   1258200         0                  0
# 2023-12-27 00:00:00-05:00  422.334  424.341  422.294  423.692   1324100         0                  0
# 2023-12-28 00:00:00-05:00  423.103  427.686  423.013  425.649   1505000         0                  0
# 2023-12-29 00:00:00-05:00  426.009  427.676  423.602  425.839   1706100         0                  0
# 2024-01-02 00:00:00-05:00  423.423  423.612  418.9    421.226   2463700         0                  0
# 2024-01-03 00:00:00-05:00  420.537  420.677  416.843  418.111   3093700         0                  0
# 2024-01-04 00:00:00-05:00  417.841  422.784  417.622  419.109   2042600         0                  0
# 2024-01-05 00:00:00-05:00  419.828  422.095  416.334  418.76    2415900         0                  0
# 2024-01-08 00:00:00-05:00  419.44   422.08   416.53   421.98    2125400         0.66               0
# 2024-01-09 00:00:00-05:00  419.1    423.7    418.54   422.6     2439300         0                  0
# 2024-01-10 00:00:00-05:00  426      429.47   424.15   428.27    2709300         0                  0
#
#
# ===== MA Actions =====
# Dividends     [0.66]
# Stock Splits  [0.0]
#
#
# ===== MSCI Info =====
# address1                      7 World Trade Center
# address2                      49th Floor 250 Greenwich Street
# city                          New York
# state                         NY
# zip                           10007
# country                       United States
# phone                         212 804 3900
# website                       https://www.msci.com
# industry                      Financial Data & Stock Exchanges
# industryKey                   financial-data-stock-exchanges
# industryDisp                  Financial Data & Stock Exchanges
# sector                        Financial Services
# sectorKey                     financial-services
# sectorDisp                    Financial Services
# longBusinessSummary           MSCI Inc., together with its subsidiaries, provides investment decision support tools for the clients to manage their investment processes worldwide. It operates through four segments: Index, Analytics, ESG and Climate, and All Other  Private Assets. The Index segment provides indexes for use in various areas of the investment process, including indexed product creation, such as ETFs, mutual funds, annuities, futures, options, structured products, over-the-counter derivatives; performance benchmarking; portfolio construction and rebalancing; and asset allocation, as well as licenses GICS and GICS Direct. The Analytics segment offers risk management, performance attribution and portfolio management content, application, and service that provides an integrated view of risk and return, and an analysis of market, credit, liquidity, and counterparty risk across asset classes; managed services, including consolidation of client portfolio data from various sources, review and reconciliation of input data and results, and customized reporting; and HedgePlatform to measure, evaluate, and monitor the risk of hedge fund investments. The ESG and Climate segment provides products and services that help institutional investors understand how ESG factors impact the long-term risk and return of their portfolio and individual security-level investments; and data, ratings, research, and tools to help investors navigate increasing regulation. The All Other  Private Assets segment includes real estate market and transaction data, benchmarks, return-analytics, climate assessments and market insights for funds, investors, and managers; business intelligence to real estate owners, managers, developers, and brokers; and offers investment decision support tools for private capital. It serves asset owners and managers, financial intermediaries, wealth managers, real estate professionals, and corporates. MSCI Inc. was incorporated in 1998 and is headquartered in New York, New York.
# fullTimeEmployees             5005
# companyOfficers               [{'maxAge': 1, 'name': 'Mr. Henry A. Fernandez', 'age': 65, 'title': 'Chairman & CEO', 'yearBorn': 1958, 'fiscalYear': 2022, 'totalPay': 2998298, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. C. D. Baer Pettit', 'age': 58, 'title': 'President, COO & Director', 'yearBorn': 1965, 'fiscalYear': 2022, 'totalPay': 2178778, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Andrew C. Wiechmann', 'age': 43, 'title': 'CFO & Interim Principal Accounting Officer', 'yearBorn': 1980, 'fiscalYear': 2022, 'totalPay': 1277719, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Robert J. Gutowski', 'age': 55, 'title': 'General Counsel', 'yearBorn': 1968, 'fiscalYear': 2022, 'totalPay': 1135503, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Scott A. Crum', 'age': 66, 'title': 'Chief Human Resources Officer', 'yearBorn': 1957, 'fiscalYear': 2022, 'totalPay': 1306184, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Jigar  Thakkar', 'title': 'CTO & Head of Engineering', 'fiscalYear': 2022, 'totalPay': 3028255, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Jeremy H. Ulan', 'title': 'Head of Investor Relations & Treasurer', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Cristina  Bondolowski', 'title': 'Chief Marketing & Communications Officer', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Remy  Briand', 'age': 57, 'title': 'Chief Product Officer', 'yearBorn': 1966, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Theodore  Niggli', 'title': 'Managing Director', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk                     6
# boardRisk                     5
# compensationRisk              6
# shareHolderRightsRisk         8
# overallRisk                   7
# governanceEpochDate           1704067200
# compensationAsOfEpochDate     1672444800
# maxAge                        86400
# priceHint                     2
# previousClose                 539.75
# open                          541.63
# dayLow                        538.0
# dayHigh                       546.83
# regularMarketPreviousClose    539.75
# regularMarketOpen             541.63
# regularMarketDayLow           538.0
# regularMarketDayHigh          546.83
# dividendRate                  5.52
# dividendYield                 0.0101
# exDividendDate                1699401600
# payoutRatio                   0.4495
# fiveYearAvgDividendYield      0.87
# beta                          1.124
# trailingPE                    45.66917
# forwardPE                     37.21307
# volume                        242154
# regularMarketVolume           242154
# averageVolume                 339877
# averageVolume10days           316180
# averageDailyVolume10Day       316180
# bid                           544.83
# ask                           580.78
# bidSize                       1000
# askSize                       800
# marketCap                     43235991552
# fiftyTwoWeekLow               451.55
# fiftyTwoWeekHigh              573.32
# priceToSalesTrailing12Months  17.902939
# fiftyDayAverage               524.8176
# twoHundredDayAverage          512.20764
# trailingAnnualDividendRate    5.39
# trailingAnnualDividendYield   0.009986104
# currency                      USD
# enterpriseValue               46964105216
# profitMargins                 0.39758998
# floatShares                   76586372
# sharesOutstanding             79091200
# sharesShort                   736912
# sharesShortPriorMonth         698198
# sharesShortPreviousMonthDate  1700006400
# dateShortInterest             1702598400
# sharesPercentSharesOut        0.0093
# heldPercentInsiders           0.03131
# heldPercentInstitutions       0.93114996
# shortRatio                    2.34
# shortPercentOfFloat           0.0108
# impliedSharesOutstanding      79091200
# bookValue                     -13.264
# lastFiscalYearEnd             1672444800
# nextFiscalYearEnd             1703980800
# mostRecentQuarter             1696032000
# earningsQuarterlyGrowth       0.199
# netIncomeToCommon             960182976
# trailingEps                   11.97
# forwardEps                    14.69
# pegRatio                      2.96
# enterpriseToRevenue           19.447
# enterpriseToEbitda            33.35
# 52WeekChange                  0.07082629
# SandP52WeekChange             0.19414937
# lastDividendValue             1.38
# lastDividendDate              1699401600
# exchange                      NYQ
# quoteType                     EQUITY
# symbol                        MSCI
# underlyingSymbol              MSCI
# shortName                     MSCI Inc.
# longName                      MSCI Inc.
# firstTradeDateEpochUtc        1195137000
# timeZoneFullName              America/New_York
# timeZoneShortName             EST
# uuid                          a72e6d80-fb03-3f21-ac37-4b8f76f60804
# messageBoardId                finmb_7844318
# gmtOffSetMilliseconds         -18000000
# currentPrice                  546.66
# targetHighPrice               640.0
# targetLowPrice                460.0
# targetMeanPrice               564.69
# targetMedianPrice             574.0
# recommendationMean            2.5
# recommendationKey             buy
# numberOfAnalystOpinions       13
# totalCash                     924713024
# totalCashPerShare             11.692
# ebitda                        1408222976
# totalDebt                     4652827136
# quickRatio                    1.268
# currentRatio                  1.361
# totalRevenue                  2415022080
# revenuePerShare               30.309
# returnOnAssets                0.17145
# grossProfits                  1844257000
# freeCashflow                  923180992
# operatingCashflow             1162503040
# earningsGrowth                0.22
# revenueGrowth                 0.116
# grossMargins                  0.82344
# ebitdaMargins                 0.58311003
# operatingMargins              0.56651
# financialCurrency             USD
# trailingPegRatio              2.5118
#
#
# ===== MSCI Historical Data =====
# Date                         Open    High     Low    Close    Volume    Dividends    Stock Splits
# 2023-12-11 00:00:00-05:00  507.71  518.43  507.71   516.61    324400            0               0
# 2023-12-12 00:00:00-05:00  518.96  526.25  513.04   526.02    319400            0               0
# 2023-12-13 00:00:00-05:00  534.71  546.97  529.1    546.37    696200            0               0
# 2023-12-14 00:00:00-05:00  551.25  559.86  538.55   542.11    510500            0               0
# 2023-12-15 00:00:00-05:00  541.51  541.51  528.49   531.58    643800            0               0
# 2023-12-18 00:00:00-05:00  531.82  536.42  525.26   532.86    564200            0               0
# 2023-12-19 00:00:00-05:00  535     544.24  534.8    542.53    351000            0               0
# 2023-12-20 00:00:00-05:00  541.72  555.78  540.14   540.18    337500            0               0
# 2023-12-21 00:00:00-05:00  544.43  553.43  541.32   553.02    317200            0               0
# 2023-12-22 00:00:00-05:00  554.75  562.7   554.75   562.28    384900            0               0
# 2023-12-26 00:00:00-05:00  562.28  563.35  558.44   561.27    145500            0               0
# 2023-12-27 00:00:00-05:00  561.57  566.93  561.57   565.62    195000            0               0
# 2023-12-28 00:00:00-05:00  566.93  573.18  566.91   570.6     245300            0               0
# 2023-12-29 00:00:00-05:00  569.44  573.32  563.86   565.65    271500            0               0
# 2024-01-02 00:00:00-05:00  560.04  561.52  551.09   555.8     364600            0               0
# 2024-01-03 00:00:00-05:00  552.91  552.91  544.84   549.87    418600            0               0
# 2024-01-04 00:00:00-05:00  547.34  562.32  547.34   559.72    368600            0               0
# 2024-01-05 00:00:00-05:00  556.2   560.21  536.36   538.05    447100            0               0
# 2024-01-08 00:00:00-05:00  541.92  543.26  536.07   543.15    347400            0               0
# 2024-01-09 00:00:00-05:00  537.83  546.7   537.82   539.75    358200            0               0
# 2024-01-10 00:00:00-05:00  541.63  546.83  538      546.66    243400            0               0
#
#
# ===== MSCI Actions =====
# Dividends     []
# Stock Splits  []
#
#
# ===== CROX Info =====
# address1                      13601 Via Varra
# city                          Broomfield
# state                         CO
# zip                           80020
# country                       United States
# phone                         303 848 7000
# website                       https://www.crocs.com
# industry                      Footwear & Accessories
# industryKey                   footwear-accessories
# industryDisp                  Footwear & Accessories
# sector                        Consumer Cyclical
# sectorKey                     consumer-cyclical
# sectorDisp                    Consumer Cyclical
# longBusinessSummary           Crocs, Inc., together with its subsidiaries, designs, develops, manufactures, markets, and distributes casual lifestyle footwear and accessories for men, women, and children worldwide. It offers various footwear products, including clogs, sandals, slides, flips, wedges, platforms, socks, boots, shoe charms, and slippers under the Crocs brand name. The company sells its products in approximately 85 countries through wholesalers, retail stores, e-commerce sites, and third-party marketplaces. Crocs, Inc. was founded in 1999 and is headquartered in Broomfield, Colorado.
# fullTimeEmployees             6680
# companyOfficers               [{'maxAge': 1, 'name': 'Mr. Andrew  Rees', 'age': 56, 'title': 'CEO & Director', 'yearBorn': 1967, 'fiscalYear': 2022, 'totalPay': 2697650, 'exercisedValue': 0, 'unexercisedValue': 20290000}, {'maxAge': 1, 'name': 'Ms. Michelle  Poole', 'age': 55, 'title': 'Executive VP & Brand President for Crocs', 'yearBorn': 1968, 'fiscalYear': 2022, 'totalPay': 1275222, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Anne  Mehlman', 'age': 42, 'title': 'Executive VP & CFO', 'yearBorn': 1981, 'fiscalYear': 2022, 'totalPay': 1280973, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Adam  Michaels', 'age': 46, 'title': 'Executive VP & Chief Digital Officer', 'yearBorn': 1977, 'fiscalYear': 2022, 'totalPay': 1076672, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Richard J. Blackshaw', 'age': 59, 'title': 'Executive VP & Brand President for HEYDUDE', 'yearBorn': 1964, 'fiscalYear': 2022, 'totalPay': 1392616, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Thomas  Britt', 'title': 'Executive VP & Chief Information Officer', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Marisa F. Jacobs', 'title': 'Global Head of Investor Relations', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Daniel P. Hart', 'age': 64, 'title': 'Executive VP and Chief Legal & Risk Officer', 'yearBorn': 1959, 'fiscalYear': 2022, 'totalPay': 1242601, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Shannon  Sisler', 'age': 49, 'title': 'Executive VP & Chief People Officer', 'yearBorn': 1974, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Erik  Olson', 'title': 'Senior Vice President of Global Sourcing & Product Execution', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk                     1
# boardRisk                     3
# compensationRisk              3
# shareHolderRightsRisk         7
# overallRisk                   3
# governanceEpochDate           1704067200
# compensationAsOfEpochDate     1672444800
# maxAge                        86400
# priceHint                     2
# previousClose                 100.12
# open                          101.19
# dayLow                        100.604
# dayHigh                       106.0
# regularMarketPreviousClose    100.12
# regularMarketOpen             101.19
# regularMarketDayLow           100.604
# regularMarketDayHigh          106.0
# beta                          1.932
# trailingPE                    9.692166
# forwardPE                     8.655145
# volume                        2223127
# regularMarketVolume           2223127
# averageVolume                 1655286
# averageVolume10days           2430250
# averageDailyVolume10Day       2430250
# bidSize                       800
# askSize                       1100
# marketCap                     6369183744
# fiftyTwoWeekLow               74.0
# fiftyTwoWeekHigh              151.32
# priceToSalesTrailing12Months  1.6135087
# fiftyDayAverage               94.9602
# twoHundredDayAverage          104.83155
# currency                      USD
# enterpriseValue               8528555008
# profitMargins                 0.17142999
# floatShares                   58601842
# sharesOutstanding             60566600
# sharesShort                   5284950
# sharesShortPriorMonth         5659041
# sharesShortPreviousMonthDate  1700006400
# dateShortInterest             1702598400
# sharesPercentSharesOut        0.087299995
# heldPercentInsiders           0.026670001
# heldPercentInstitutions       0.93235
# shortRatio                    3.92
# shortPercentOfFloat           0.1205
# impliedSharesOutstanding      60566600
# bookValue                     19.741
# priceToBook                   5.326985
# lastFiscalYearEnd             1672444800
# nextFiscalYearEnd             1703980800
# mostRecentQuarter             1696032000
# earningsQuarterlyGrowth       0.045
# netIncomeToCommon             676715008
# trailingEps                   10.85
# forwardEps                    12.15
# pegRatio                      0.85
# lastSplitFactor               2:1
# lastSplitDate                 1181865600
# enterpriseToRevenue           2.161
# enterpriseToEbitda            8.007
# 52WeekChange                  -0.21233577
# SandP52WeekChange             0.19414937
# exchange                      NMS
# quoteType                     EQUITY
# symbol                        CROX
# underlyingSymbol              CROX
# shortName                     Crocs, Inc.
# longName                      Crocs, Inc.
# firstTradeDateEpochUtc        1139409000
# timeZoneFullName              America/New_York
# timeZoneShortName             EST
# uuid                          28166f72-2353-3b0b-bc03-31981380e626
# messageBoardId                finmb_13639284
# gmtOffSetMilliseconds         -18000000
# currentPrice                  105.16
# targetHighPrice               160.0
# targetLowPrice                79.0
# targetMeanPrice               125.0
# targetMedianPrice             130.0
# recommendationMean            1.8
# recommendationKey             buy
# numberOfAnalystOpinions       12
# totalCash                     127320000
# totalCashPerShare             2.102
# ebitda                        1065131008
# totalDebt                     2286689024
# quickRatio                    0.841
# currentRatio                  1.511
# totalRevenue                  3947411968
# debtToEquity                  190.516
# revenuePerShare               63.987
# returnOnAssets                0.13862
# returnOnEquity                0.73915
# grossProfits                  1860282000
# freeCashflow                  703901632
# operatingCashflow             937182976
# earningsGrowth                0.055
# revenueGrowth                 0.062
# grossMargins                  0.53540003
# ebitdaMargins                 0.26983
# operatingMargins              0.26188
# financialCurrency             USD
# trailingPegRatio
#
#
# ===== CROX Historical Data =====
# ...
# twoHundredDayAverage          99.90835
# trailingAnnualDividendRate    3.32
# trailingAnnualDividendYield   0.027438017
# currency                      USD
# enterpriseValue               108059697152
# profitMargins                 0.21798
# floatShares                   707745121
# sharesOutstanding             710545024
# sharesShort                   30676500
# sharesShortPriorMonth         31512086
# sharesShortPreviousMonthDate  1700006400
# dateShortInterest             1702598400
# sharesPercentSharesOut        0.040900003
# heldPercentInsiders           0.00508
# heldPercentInstitutions       0.74513
# shortRatio                    8.41
# shortPercentOfFloat           0.0433
# impliedSharesOutstanding      1209529984
# bookValue                     9.928
# priceToBook                   12.241136
# lastFiscalYearEnd             1672444800
# nextFiscalYearEnd             1703980800
# mostRecentQuarter             1696032000
# earningsQuarterlyGrowth       239.416
# netIncomeToCommon             1796934016
# trailingEps                   2.39
# forwardEps                    5.24
# pegRatio                      5.52
# enterpriseToRevenue           13.108
# 52WeekChange                  0.4225253
# SandP52WeekChange             0.19414937
# lastDividendValue             0.8
# lastDividendDate              1698364800
# exchange                      NYQ
# quoteType                     EQUITY
# symbol                        BX
# underlyingSymbol              BX
# shortName                     Blackstone Inc.
# longName                      Blackstone Inc.
# firstTradeDateEpochUtc        1182519000
# timeZoneFullName              America/New_York
# timeZoneShortName             EST
# uuid                          cc7f5d4a-4577-3811-a49a-1397cefb3426
# messageBoardId                finmb_671980
# gmtOffSetMilliseconds         -18000000
# currentPrice                  121.53
# targetHighPrice               150.0
# targetLowPrice                95.0
# targetMeanPrice               119.78
# targetMedianPrice             119.0
# recommendationMean            2.3
# recommendationKey             buy
# numberOfAnalystOpinions       18
# totalCash                     3193616896
# totalCashPerShare             4.495
# totalDebt                     13222924288
# quickRatio                    1.089
# currentRatio                  1.132
# totalRevenue                  8243745792
# debtToEquity                  70.295
# revenuePerShare               10.972
# returnOnAssets                0.07516
# returnOnEquity                0.15973
# grossProfits                  7053217000
# operatingCashflow             3876353024
# earningsGrowth                234.532
# revenueGrowth                 2.041
# grossMargins                  0.92130995
# operatingMargins              0.46583998
# financialCurrency             USD
# trailingPegRatio              3.7441
#
#
# ===== BX Historical Data =====
# Date                         Open    High     Low    Close    Volume    Dividends    Stock Splits
# 2023-12-11 00:00:00-05:00  112.65  113.27  112.33   112.99   3566800            0               0
# 2023-12-12 00:00:00-05:00  113.12  113.24  112.09   113.21   2392200            0               0
# 2023-12-13 00:00:00-05:00  113.2   119.99  112.44   119.75   4983600            0               0
# 2023-12-14 00:00:00-05:00  121     128.66  120.67   128.47   7687300            0               0
# 2023-12-15 00:00:00-05:00  127.69  130.41  127.04   129.37   7990000            0               0
# 2023-12-18 00:00:00-05:00  129.5   129.74  125.89   125.96   4605500            0               0
# 2023-12-19 00:00:00-05:00  125.56  129.31  125.04   128.29   5025500            0               0
# 2023-12-20 00:00:00-05:00  127.83  129.54  125.95   126.1    5627300            0               0
# 2023-12-21 00:00:00-05:00  127.4   129.21  126.75   129.14   3810900            0               0
# 2023-12-22 00:00:00-05:00  129.74  132.08  129.24   130.69   3342400            0               0
# 2023-12-26 00:00:00-05:00  130.67  132.01  130.34   131.37   2485000            0               0
# 2023-12-27 00:00:00-05:00  131.07  133.43  130.58   132.61   3561200            0               0
# 2023-12-28 00:00:00-05:00  132.5   133.53  132.04   133.13   2087900            0               0
# 2023-12-29 00:00:00-05:00  132.87  133.24  130.28   130.92   2049000            0               0
# 2024-01-02 00:00:00-05:00  129.2   129.75  126.77   128.27   4500900            0               0
# 2024-01-03 00:00:00-05:00  125.05  125.45  121.58   122.35   5391000            0               0
# 2024-01-04 00:00:00-05:00  122.25  124.19  121.6    122.9    3215700            0               0
# 2024-01-05 00:00:00-05:00  121.5   123.88  120.98   122.21   2747600            0               0
# 2024-01-08 00:00:00-05:00  122.58  122.93  121.22   122.34   4273200            0               0
# 2024-01-09 00:00:00-05:00  120.54  121.71  119.62   121      5883400            0               0
# 2024-01-10 00:00:00-05:00  120.83  122.05  120.05   121.53   4049300            0               0
#
#
# ===== BX Actions =====
# Dividends     []
# Stock Splits  []
#
#
# ===== FICO Info =====
# address1                      5 West Mendenhall
# address2                      Suite 105
# city                          Bozeman
# state                         MT
# zip                           59715
# country                       United States
# phone                         (406) 982-7276
# website                       https://www.fico.com
# industry                      Software - Application
# industryKey                   software-application
# industryDisp                  Software - Application
# sector                        Technology
# sectorKey                     technology
# sectorDisp                    Technology
# longBusinessSummary           Fair Isaac Corporation develops analytic, software, and digital decisioning technologies and services that enable businesses to automate, enhance, and connect decisions in the Americas, Europe, the Middle East, Africa, and the Asia Pacific. The company operates in two segments, Scores and Software. The Software segment provides pre-configured analytic and decision management solution designed for various business needs or processes, such as account origination, customer management, customer engagement, fraud detection, financial crimes compliance, and marketing, as well as associated professional services. This segment also offers FICO Platform, a modular software offering designed to support advanced analytic and decision use cases, as well as stand-alone analytic and decisioning software that can be configured by customers to address a wide range of business use cases. The Scores segment provides business-to-business scoring solutions and services for consumers that give clients access to predictive credit and other scores that can be integrated into their transaction streams and decision-making processes, as well as business-to-consumer scoring solutions comprising myFICO.com subscription offerings. It offers FICO Customer Analytics, FICO Responsible AI, FICO Advisors, FICO Business Outcome Simulator, FICO Forecaster, FICO TRIAD Customer Manager, FICO Blaze Advisor, FICO Xpress Optimization, FICO Falcon Fraud Manager, FICO Analytics Workbench, FICO Data Orchestrator, FICO DMP Streaming, FICO Decision Optimizer, and FICO Strategy Director, as well as software implementation and configuration services. The company markets its products and services primarily through its direct sales organization and indirect channels, as well as online. The company was formerly known as Fair Isaac & Company, Inc. and changed its name to Fair Isaac Corporation in July 1992. Fair Isaac Corporation was founded in 1956 and is headquartered in Bozeman, Montana.
# fullTimeEmployees             3455
# companyOfficers               [{'maxAge': 1, 'name': 'Mr. William J. Lansing', 'age': 65, 'title': 'CEO & Director', 'yearBorn': 1958, 'fiscalYear': 2022, 'totalPay': 1971770, 'exercisedValue': 0, 'unexercisedValue': 9491125}, {'maxAge': 1, 'name': 'Mr. Mark Russell Scadina', 'age': 54, 'title': 'Executive VP, General Counsel & Corporate Secretary', 'yearBorn': 1969, 'fiscalYear': 2022, 'totalPay': 730084, 'exercisedValue': 0, 'unexercisedValue': 1254181}, {'maxAge': 1, 'name': 'Mr. James M. Wehmann', 'age': 58, 'title': 'Executive Vice President of Scores', 'yearBorn': 1965, 'fiscalYear': 2022, 'totalPay': 886846, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Steven P. Weber', 'title': 'Executive VP & CFO', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Michael S. Leonard', 'age': 58, 'title': 'VP & Chief Accounting Officer', 'yearBorn': 1965, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Amir  Hermelin', 'title': 'VP & CTO', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Don  Peterson', 'age': 61, 'title': 'Vice President of Global Sales & Client Success', 'yearBorn': 1962, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Nikhil  Behl', 'age': 49, 'title': 'Executive VP & Chief Marketing Officer', 'yearBorn': 1974, 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Richard Shawn Deal', 'age': 56, 'title': 'Executive VP & Chief Human Resources Officer', 'yearBorn': 1967, 'fiscalYear': 2022, 'totalPay': 349391, 'exercisedValue': 101907, 'unexercisedValue': 17309}, {'maxAge': 1, 'name': 'Mr. John  Chen', 'title': 'Managing Director of China Operations', 'fiscalYear': 2022, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk                     10
# boardRisk                     5
# compensationRisk              3
# shareHolderRightsRisk         7
# overallRisk                   7
# governanceEpochDate           1704067200
# compensationAsOfEpochDate     1672444800
# maxAge                        86400
# priceHint                     2
# previousClose                 1159.66
# open                          1168.33
# dayLow                        1165.77
# dayHigh                       1200.34
# regularMarketPreviousClose    1159.66
# regularMarketOpen             1168.33
# regularMarketDayLow           1165.77
# regularMarketDayHigh          1200.34
# exDividendDate                1488326400
# fiveYearAvgDividendYield      0.09
# beta                          1.267
# trailingPE                    70.93558
# forwardPE                     41.77619
# volume                        134535
# regularMarketVolume           134535
# averageVolume                 198952
# averageVolume10days           127230
# averageDailyVolume10Day       127230
# ask                           1907.98
# bidSize                       900
# askSize                       800
# marketCap                     29662003200
# fiftyTwoWeekLow               586.6
# fiftyTwoWeekHigh              1200.34
# priceToSalesTrailing12Months  19.597546
# fiftyDayAverage               1068.868
# twoHundredDayAverage          874.57965
# currency                      USD
# enterpriseValue               31427072000
# profitMargins                 0.28369
# floatShares                   23982283
# sharesOutstanding             24713600
# sharesShort                   662023
# sharesShortPriorMonth         673022
# sharesShortPreviousMonthDate  1700006400
# dateShortInterest             1702598400
# sharesPercentSharesOut        0.026800001
# heldPercentInsiders           0.02016
# heldPercentInstitutions       0.89169
# shortRatio                    3.46
# shortPercentOfFloat           0.0378
# impliedSharesOutstanding      24713600
# bookValue                     -27.775
# lastFiscalYearEnd             1696032000
# nextFiscalYearEnd             1727654400
# mostRecentQuarter             1696032000
# earningsQuarterlyGrowth       0.118
# netIncomeToCommon             429375008
# trailingEps                   16.92
# forwardEps                    28.73
# pegRatio                      2.56
# lastSplitFactor               3:2
# lastSplitDate                 1078963200
# enterpriseToRevenue           20.764
# enterpriseToEbitda            47.978
# 52WeekChange                  0.9149575
# SandP52WeekChange             0.19414937
# lastDividendValue             0.02
# lastDividendDate              1488326400
# exchange                      NYQ
# quoteType                     EQUITY
# symbol                        FICO
# underlyingSymbol              FICO
# shortName                     Fair Isaac Corproation
# longName                      Fair Isaac Corporation
# firstTradeDateEpochUtc        553959000
# timeZoneFullName              America/New_York
# timeZoneShortName             EST
# uuid                          55b4335e-24c0-37ae-80bb-efabaa3f157a
# messageBoardId                finmb_270427
# gmtOffSetMilliseconds         -18000000
# currentPrice                  1200.23
# targetHighPrice               1350.0
# targetLowPrice                725.0
# targetMeanPrice               1094.06
# targetMedianPrice             1089.86
# recommendationMean            2.4
# recommendationKey             buy
# numberOfAnalystOpinions       12
# totalCash                     136778000
# totalCashPerShare             5.535
# ebitda                        655027008
# totalDebt                     1901896960
# quickRatio                    1.427
# currentRatio                  1.513
# totalRevenue                  1513556992
# revenuePerShare               60.576
# returnOnAssets                0.26549998
# grossProfits                  1202504000
# freeCashflow                  420066368
# operatingCashflow             468915008
# earningsGrowth                0.132
# revenueGrowth                 0.118
# grossMargins                  0.79449
# ebitdaMargins                 0.43277
# operatingMargins              0.42516
# financialCurrency             USD
# trailingPegRatio              2.4267
#
#
# ===== FICO Historical Data =====
# Date                          Open     High      Low    Close    Volume    Dividends    Stock Splits
# 2023-12-11 00:00:00-05:00  1131.81  1147.52  1123.93  1145.82    133100            0               0
# 2023-12-12 00:00:00-05:00  1140.19  1159.67  1132.73  1159.22    160600            0               0
# 2023-12-13 00:00:00-05:00  1163.29  1183.79  1157.76  1166.78    236300            0               0
# 2023-12-14 00:00:00-05:00  1181.69  1185.42  1123.56  1129.59    423600            0               0
# 2023-12-15 00:00:00-05:00  1127.12  1136.63  1121.53  1129.78    467100            0               0
# 2023-12-18 00:00:00-05:00  1135     1152.53  1130.74  1148.77    359600            0               0
# 2023-12-19 00:00:00-05:00  1150.26  1156.39  1149.16  1152.51    322300            0               0
# 2023-12-20 00:00:00-05:00  1152.51  1180.56  1149.92  1155.15    130000            0               0
# 2023-12-21 00:00:00-05:00  1162.23  1172.2   1154.57  1165.46    135200            0               0
# 2023-12-22 00:00:00-05:00  1175.61  1175.61  1160.26  1168.88     67100            0               0
# 2023-12-26 00:00:00-05:00  1175.17  1175.17  1160.57  1164.62    111400            0               0
# 2023-12-27 00:00:00-05:00  1163.99  1175.35  1162.34  1170.61    115200            0               0
# 2023-12-28 00:00:00-05:00  1172.28  1173.71  1167.04  1169.34     62800            0               0
# 2023-12-29 00:00:00-05:00  1168.1   1176.22  1155.27  1164.01     97000            0               0
# 2024-01-02 00:00:00-05:00  1152.4   1158.01  1119.88  1131.16    190800            0               0
# 2024-01-03 00:00:00-05:00  1131.16  1135     1116.12  1122.37    158600            0               0
# 2024-01-04 00:00:00-05:00  1124.09  1132.93  1115.1   1117.46    127700            0               0
# 2024-01-05 00:00:00-05:00  1115.52  1132.4   1113.19  1115.46    164600            0               0
# 2024-01-08 00:00:00-05:00  1120.92  1154.52  1115.81  1152.43    134200            0               0
# 2024-01-09 00:00:00-05:00  1144.84  1163.94  1139.75  1159.66    110000            0               0
# 2024-01-10 00:00:00-05:00  1168.33  1200.34  1165.77  1200.23    141300            0               0
#
#
# ===== FICO Actions =====
# Dividends     []
# Stock Splits  []

# %%
# show news
msft.news
